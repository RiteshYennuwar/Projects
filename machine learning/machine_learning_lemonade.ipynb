# %%
import pandas as pd
df = pd.read_csv('Lemonade.csv')
df.head()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 1  02/01/2017     Monday         28.9      1.33      15    0.3     13
# 2  03/01/2017    Tuesday         34.5      1.33      27    0.3     15
# 3  04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 4  05/01/2017   Thursday         42.4      1.00      33    0.3     18

# %%
df.shape
# Out:
# (365, 7)

# %%
# releation between sales and temperature 
#sales and rainfall
#sales and flyers
#sales and perice

# %%
import matplotlib.pyplot as plt
print(df['Temperature'].corr(df['Sales']))
plt.scatter(df['Temperature'],df['Sales'])
plt.xlabel('temperature')
plt.ylabel('sales')
plt.show()
# Out:
# 0.9898320849779687

# %%
print(df['Rainfall'].corr(df['Sales']))
plt.scatter(df['Rainfall'],df['Sales'])
plt.xlabel('rainfall')
plt.ylabel('sales')
plt.show()
# Out:
# -0.9092139324101026

# %%
plt.scatter(df['Flyers'],df['Sales'])
plt.ylabel('sales')
plt.show()

# %%
print(df['Price'].corr(df['Sales']))
plt.scatter(df['Price'],df['Sales'])
plt.xlabel('price')
plt.ylabel('sales')
plt.show()
# Out:
# 0.5129076895636262

# %%
#regression for only rainfall , temperature and flyers

# %%
x = df[['Temperature','Rainfall','Flyers']].values
# x = df.iloc[:,2:5].values
y = df.iloc[:,6].values
print(x)
print(y)
# Out:
# [[27.    2.   15.  ]
#  [28.9   1.33 15.  ]
#  [34.5   1.33 27.  ]
#  ...
#  [39.5   1.25 17.  ]
#  [30.9   1.43 22.  ]
#  [15.1   2.5   9.  ]]
# [10 13 15 17 18 11 13 15 17 18 12 14 15 17 18 12 14 16 17 12 14 16 17 12
#  14 16 17 13 14 17 18 18 20 21 22 18 20 21 22 19 20 21 22 18 19 20 21 18
#  19 20 21 18 19 20 21 18 19 20 22 23 24 24 25 23 24 24 25 23 24 24 25 23
#  23 24 24 25 23 23 24 24 25 23 23 24 25 25 23 24 24 25 25 26 26 27 28 25
#  26 26 27 25 26 27 27 25 26 27 27 25 26 27 27 25 26 27 27 25 25 26 27 27
#  29 29 30 31 28 29 29 30 31 28 29 29 30 31 28 29 29 30 31 28 29 30 31 28
#  29 30 31 29 29 30 31 31 33 35 38 32 34 36 39 32 35 36 40 32 35 36 41 31
#  32 35 37 41 31 33 35 37 42 31 33 35 38 43 38 35 34 32 39 35 34 33 40 35
#  34 33 40 35 34 33 41 36 35 33 42 37 35 33 32 43 38 35 34 32 32 31 30 29
#  32 31 30 29 32 31 30 29 29 32 31 30 30 29 32 31 30 30 29 32 30 30 29 32
#  30 30 29 29 28 27 26 26 29 28 27 26 26 28 27 26 26 28 27 26 26 28 27 26
# ...

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
# print(x_train.shape)
# print(x_test.shape)

# %%
reg = LinearRegression().fit(x_train,y_train)

y_pred = reg.predict(x_test)
y_pred
# Out:
# array([32.83547606, 20.90990165, 11.76837935, 21.38974336, 18.85934106,
#        34.43286504, 22.52464924, 27.7659493 , 33.2300578 , 29.28206452,
#         7.88793431, 18.11558774, 22.0422039 , 17.55790146, 30.20588436,
#        23.90993393,  9.49208585, 24.63580391, 20.4272001 , 27.2653956 ,
#        18.12579948, 35.19038738, 24.39962305, 28.43576844, 30.22343568,
#        34.51354946, 32.07420372, 25.40803772, 14.65073725, 15.56737791,
#        14.46747776, 25.39463301, 23.38793962, 17.47721704, 33.01551028,
#        27.12454603, 23.19434029, 15.8309887 , 12.37773252, 22.74321528,
#        28.66578838, 13.53015742, 17.09340406, 25.63691129, 28.42144239,
#        29.22173897, 23.97009908, 20.09953376, 10.01966054, 21.66405942,
#        29.20852697, 12.9276826 , 25.8874505 , 28.29136159, 42.33906334,
#        13.4665754 , 25.84516869, 18.26625243, 11.60928101, 23.80402659,
#        29.36330597, 12.53297275, 24.2973688 , 19.92690261, 26.53293578,
# ...

# %%
import numpy as np

mse = np.mean(np.square(np.subtract(y_test,y_pred)))
mse
# Out:
# 0.8641937052436436

# %%
# evaluation

#loss function : least
#accuracy : high -- r2 score
#coefficient of determination

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.8641937052436436

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9824577062575081
